# %% [markdown]
# <font face="微软雅黑" size=5 color=#A52A2A > Lesson 8 图像

# %%
## 画图必备
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.patches as patches

# %% [markdown]
# # 几种典型的图像应用场景
# + 影像图片 picture
# + 表面拓扑 colormap, contour
# + 热图 heatmap
# + 条形码或二维码 Barcode
# + ……

# %% [markdown]
# # 影像图片 picture/image

# %% [markdown]
# ### 练习：读取并展示图片文件
# + 关掉坐标轴
# + 图片加字
# + 图片裁剪
# + 抠图
# + 加水印

# %%
boy = plt.imread('boy.jpg')  
plt.imshow(boy)
plt.axis('off')
print(boy.shape)
# Out:
# (1800, 1200, 3)

# %%
hyt = plt.imread('hyt.png')  
plt.imshow(hyt[175:825,325:1700])
print(hyt.shape)
# Out:
# (958, 2100, 4)

# %%
fig, ax = plt.subplots()
fig.set_size_inches(6,6)
im = ax.imshow(boy[0:1200,:])
patch = patches.Circle((600, 600), radius = 600, transform = ax.transData)
#patch = patches.Rectangle((250, 180), 650, 700,  transform = ax.transData)
im.set_clip_path(patch)
#ax.text(200, 1000, 'This is LEO.', size=36, color = "grey", alpha=0.5)
axins = ax.inset_axes([0.2, 0.2, 0.47, 0.17])
axins.imshow(hyt[175:825,325:1700], alpha=0.5)
axins.axis('off')
ax.axis('off')
# Out:
# (-0.5, 1199.5, 1199.5, -0.5)

# %% [markdown]
# ### 练习：给10张照片加水印
# + glob
# + for 循环
# + imshow

# %% [markdown]
# # 热图 heatmap

# %%
vegetables = ["cucumber", "tomato", "lettuce", "asparagus",
              "potato", "wheat", "barley"]
farmers = ["Farmer Joe", "Upland Bros.", "Smith Gardening",
           "Agrifun", "Organiculture", "BioGoods Ltd.", "Cornylee Corp."]

harvest = np.array([[0.8, 2.4, 2.5, 3.9, 0.0, 4.0, 0.0],
                    [2.4, 0.0, 4.0, 1.0, 2.7, 0.0, 0.0],
                    [1.1, 2.4, 0.8, 4.3, 1.9, 4.4, 0.0],
                    [0.6, 0.0, 0.3, 0.0, 3.1, 0.0, 0.0],
                    [0.7, 1.7, 0.6, 2.6, 2.2, 6.2, 0.0],
                    [1.3, 1.2, 0.0, 0.0, 0.0, 3.2, 5.1],
                    [0.1, 2.0, 0.0, 1.4, 0.0, 1.9, 6.3]])


fig, ax = plt.subplots()
im = ax.imshow(harvest)

# Show all ticks and label them with the respective list entries
ax.set_xticks(np.arange(len(farmers)), labels=farmers)
ax.set_yticks(np.arange(len(vegetables)), labels=vegetables)

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
for i in range(len(vegetables)):
    for j in range(len(farmers)):
        text = ax.text(j, i, harvest[i, j],
                       ha="center", va="center", color="w")

ax.set_title("Harvest of local farmers (in tons/year)")
cbar = fig.colorbar(im)
fig.tight_layout()
plt.show()

# %% [markdown]
# # 表面拓扑图
# + 数据形式
# + 表达含义

# %% [markdown]
# ### 练习：数据读取和索引

# %%
Radata = pd.read_csv ('./documents/newRa.csv')
z = np.array(Radata['z']).reshape(101, 99)
vmin = -70
vmax = 70
fig, ax = plt.subplots(figsize=(6.5,4))
ax.set_title('Particle size=4'+"$\mu m$", fontsize=12)
ax.set_xlabel('X/mm')
ax.set_ylabel('Y/mm')
ax.set_xticks(np.linspace(0, 100, 6), labels=[0, 0.2, 0.4, 0.6, 0.8, 1.])
ax.set_yticks(np.linspace(0, 100, 6), labels=[0, 0.2, 0.4, 0.6, 0.8, 1.])
im = ax.imshow(z, cmap='RdBu', vmin=vmin, vmax=vmax)
ax.set_xlim(0, 100)
ax.set_ylim(100, 0)
ax.tick_params('both', direction='out', labelsize=10)
cbar = fig.colorbar(im, extend='both')
cbar.set_label("Height/$\mu m$")

# %% [markdown]
# ### 练习
# + 新建画布
# + 画布尺寸设置
# + x和y轴命名
# + 坐标参数设置
# + 坐标范围限定
# + 输出图像
# + 添加colorbar

# %%
z = np.array(Radata['z']).reshape(101, 99)

# %% [markdown]
# + <font size=4 color=blue > 作业
#     + <font size=2 color=blue > 完成所有上课练习
#     + <font size=2 color=blue > 自学条形码
